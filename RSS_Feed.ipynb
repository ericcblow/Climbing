# %%
from IPython.display import clear_output
# !pip install feedparser
clear_output()

# %%
from IPython.display import clear_output
import feedparser
import csv
from datetime import date

# %%
# URL of the RSS feed
rss_url = "https://www.mountainproject.com/rss/user-ticks/200907207"

# Parse the RSS feed
feed = feedparser.parse(rss_url)
print(feed)

# # Open a CSV file to write
# with open("rss_feed_data.csv", "w", newline="", encoding="utf-8") as csvfile:
#     # Define CSV writer
#     csvwriter = csv.writer(csvfile)
    
#     # Write the header
#     csvwriter.writerow(["title", "description", "link", "language", "lastBuildDate"])
    
#     # Loop through each entry in the feed and write to CSV
#     for entry in feed.entries:
#         title = entry.get("title", "")
#         link = entry.get("link", "")
#         pub_date = entry.get("pubDate", "")
#         description = entry.get("description", "")  
        
#         csvwriter.writerow([title, link, pub_date, description])

# print("RSS feed data has been saved to rss_feed_data.csv.")
# Out:
# {'bozo': True, 'entries': [{'title': 'Tick: Birdland (5.7+)', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://www.mountainproject.com/rss/user-ticks/200907207', 'value': 'Tick: Birdland (5.7+)'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://www.mountainproject.com/route/105733115/birdland'}], 'link': 'https://www.mountainproject.com/route/105733115/birdland', 'id': 'MPObject_127409425', 'guidislink': False, 'published': 'Sun, 01 Dec 2024 22:45:58 +0000', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=12, tm_mday=1, tm_hour=22, tm_min=45, tm_sec=58, tm_wday=6, tm_yday=336, tm_isdst=0), 'summary': '<div class="fr-view"><p>A beautiful climb with a variety of moves. This route is nice to do in the cooler months, as it\'s in the sun all day. Approach as to &quot;The Brass Wall.&quot; This route is on &quot;Brass Wall Left.&quot; The first pitch is also the start of a climb called &quot;The Big Horn.&quot; Starts on a ledge with 
# ...
